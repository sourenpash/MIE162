# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Instal Firefox, Selenium, Gecko Driver, Beautiful Soup

# %%
#Install firefox
# !apt-get update
# !apt install firefox

#Install selenium
# !pip install selenium

#Updating and installing firefox libraries
# !apt-get update && apt-get install -y wget bzip2 libxtst6 libgtk-3-0 libx11-xcb-dev libdbus-glib-1-2 libxt6 libpci-dev && rm -rf /var/lib/apt/lists/*

#Installing Geck Driver
# !wget https://github.com/mozilla/geckodriver/releases/download/v0.24.0/geckodriver-v0.24.0-linux64.tar.gz
# !tar -xvzf geckodriver*
# !chmod +x geckodriver
# !export PATH=$PATH:/path-to-extracted-file/.

#Instal beautifulsoup
# !pip install beautifulsoup4

# %% [markdown]
# ### Import Dependencies

# %%
import selenium.webdriver as webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options as FirefoxOptions

import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By

import random
import time

# %% [markdown]
# ### Define Position and Location

# %%
## Enter a job position
position = "data+scientist"
## Enter a location (City, State or Zip or remote)
locations = "remote"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])
print(url)
# Out:
# https://www.indeed.com/jobs?q=engineer&l=united+states

# %% [markdown]
# ### Set Path to Webdriver

# %%
driver_path = '/content/geckodriver'
firefox_driver_path = '/content/geckodriver'
user_agent = 'Mozilla'
firefox_options = FirefoxOptions()
firefox_options.add_argument('--headless')
driver = webdriver.Firefox(options=firefox_options)

# %% [markdown]
# ### Scrape Job Postings

# %%
## Number of postings to scrape
postings = 100

jn=0
for i in range(0, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(3)

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')
    #print(jobs)

    for job in jobs:
        #print(job)
        result_html = job.get_attribute('innerHTML')
        #print(result_html)
        soup = BeautifulSoup(result_html, 'html.parser')
        #print(soup , '\n')

        jn += 1

        liens = job.find_elements(By.TAG_NAME, "a")
        #print(liens)
        links = liens[0].get_attribute("href")
        #print(links)

        title = soup.select('.jobTitle')[0].get_text().strip()
        print(title)

        #company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip()
        #print(company)
        try:
            company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip()
            #print(company)
        except:
            company = 'Nan'
        print(company)
        #location = soup.select('.companyLocation')[0].get_text().strip() #origional
        #location = soup.select('.company_location')[0].get_text().strip()
        location = soup.find_all(attrs={'data-testid': 'text-location'})[0].get_text().strip()
        print(location)
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''

        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))

# %%
dataframe.head()

# %% [markdown]
# ### Scrape Full Job Descriptions

# %%
Links_list = dataframe['Links'].tolist()
#Links_list

# %%
descriptions=[]
for i in Links_list:
    driver.get(i)
    driver.implicitly_wait(random.randint(3, 8))
    jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
    descriptions.append(jd)
    time.sleep(random.randint(5,10))

dataframe['Descriptions'] = descriptions

# %% [markdown]
# ### Save Results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe.head()
# Out:
#                                                 Title  \
# 0                         Rotating Equipment Engineer
# 1                    Early Career Mechanical Engineer
# 2                                 Mechanical Engineer
# 3                        Process Development Engineer
# 4                                 Mechanical Engineer
# 5                 TD Quality and Reliability Engineer
# 6                                       Test Engineer
# 7                                  Reservoir Engineer
# 8                         Early Career Field Engineer
# 9                                  Associate Engineer
# 10                                     Wells Engineer
# 11               CONTINUOUS IMPROVEMENT (CI) ENGINEER
# 12                          Advanced Quality Engineer
# 13                      Process Automation Engineer I
# 14  Entry-Level Hardware Systems Engineer (Support...
#
#                                    Company  \
# 0                                       bp
# 1                                      WSP
# 2                                       bp
# 3                               ExxonMobil
# 4                         BASF Corporation
# 5                                    INTEL
# 6                             Baker Hughes
# 7                Endeavor Energy Resources
# 8                                      WSP
# 9   Energy Transfer Family of Partnerships
# 10                                   Shell
# 11                           Louis Vuitton
# 12                                      3M
# 13                        Freeport McMoRan
# 14                                     KBR
#
#                                  Location Rating                       Date  \
# 0                        Blaine, WA 98230    NaN    PostedPosted 5 days ago
# 1       Seattle, WA 98104 (Downtown area)    NaN    PostedPosted 7 days ago
# 2                        Blaine, WA 98230    NaN    PostedPosted 5 days ago
# 3                             Baytown, TX    NaN  PostedPosted 30+ days ago
# 4                        Bishop, TX 78343    NaN    PostedPosted 5 days ago
# 5                         Santa Clara, CA    NaN   PostedPosted 18 days ago
# 6                     Deer Park, TX 77536    NaN   PostedPosted 21 days ago
# 7                             Midland, TX    NaN                PostedToday
# 8                         Federal Way, WA    NaN    PostedPosted 7 days ago
# 9                              Ganado, TX    NaN                PostedToday
# 10                            Houston, TX    NaN    PostedPosted 7 days ago
# 11                           Alvarado, TX    NaN    PostedPosted 8 days ago
# 12                        San Antonio, TX    NaN  PostedPosted 30+ days ago
# 13  El Paso, TX 79915 (Lower Valley area)    NaN    PostedPosted 2 days ago
# 14      Houston, TX 77002 (Downtown area)    NaN   PostedPosted 15 days ago
#
#                         Salary  \
# 0                          NaN
# 1     $66,400 - $99,600 a year
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5   $118,860 - $196,720 a year
# 6                          NaN
# 7                          NaN
# 8     $66,400 - $99,600 a year
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12   $93,033 - $113,708 a year
# 13                         NaN
# 14                         NaN
#
#                                           Description  \
# 0   Up to 10% travel should be expected with this ...
# 1   Takes part in providing local technical assist...
# 2   Up to 10% travel should be expected with this ...
# 3   The process development engineer may also focu...
# 4   As a valued member, you will develop and imple...
# 5   Develops, applies, and maintains quality and r...
# 6   Collaborating with Mechanical and Electrical e...
# 7   Utilize knowledge of relevant reservoir engine...
# 8   WSP is currently initiating a search for a Ful...
# 9   Build and maintain facility process simulation...
# 10  The well engineer utilizes available digital t...
# 11  You will be responsible for researching, plann...
# 12  Provide quality engineering services for new a...
# 13  Under close supervision, maintain the performa...
# 14  Entry-Level Hardware Systems Engineer (Support...
#
#                                                 Links  \
# 0   https://www.indeed.com/rc/clk?jk=c11c88e8b3b91...
# 1   https://www.indeed.com/rc/clk?jk=1b44b5c6de43e...
# 2   https://www.indeed.com/rc/clk?jk=98a8771ed0b90...
# 3   https://www.indeed.com/rc/clk?jk=6f44c7e104f3e...
# 4   https://www.indeed.com/rc/clk?jk=da2ff63a9541e...
# 5   https://www.indeed.com/rc/clk?jk=f7b6e6478fc14...
# 6   https://www.indeed.com/rc/clk?jk=ca12e7e42bdc5...
# 7   https://www.indeed.com/rc/clk?jk=08396f657fdfc...
# 8   https://www.indeed.com/rc/clk?jk=ab46725155691...
# 9   https://www.indeed.com/rc/clk?jk=3b7c5fa6b7ade...
# 10  https://www.indeed.com/rc/clk?jk=60b40543ddd3f...
# 11  https://www.indeed.com/rc/clk?jk=21c308d2939a6...
# 12  https://www.indeed.com/rc/clk?jk=81a6646105e40...
# 13  https://www.indeed.com/rc/clk?jk=a68bd121141bf...
# 14  https://www.indeed.com/rc/clk?jk=b64ad24e16617...
#
#                                          Descriptions
# 0   Location\nUnited States of America - Washingto...
# 1   Who We Are\nAt WSP, we are driven by inspiring...
# 2   Location\nUnited States of America - Washingto...
# 3   About us\n\nAt ExxonMobil, our vision is to le...
# 4   Now Hiring! Mechanical Engineer\nBishop, TX\nT...
# 5   Job Description\n\nDevelops, applies, and main...
# 6   Test Engineer\nAre you inspired to work in the...
# 7   As one of the largest employers in the Permian...
# 8   Who We Are\nAt WSP, we are driven by inspiring...
# 9   Summary:\nThe Associate Engineer will provide ...
# 10  What’s the role?\nThe Well Engineer will suppo...
# 11  POSTE\nSince 1854, the innovation and creativi...
# 12  Job Description:\nAdvanced Quality Engineer, 3...
# 13  Freeport-McMoRan is a leading international mi...
# 14  Title:\nEntry-Level Hardware Systems Engineer ...
