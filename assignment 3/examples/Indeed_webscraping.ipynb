# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Instal Firefox, Selenium, Gecko Driver, Beautiful Soup

# %%
#Install firefox
# !apt-get update
# !apt install firefox

#Install selenium
# %pip install selenium

#Updating and installing firefox libraries
# !apt-get update && apt-get install -y wget bzip2 libxtst6 libgtk-3-0 libx11-xcb-dev libdbus-glib-1-2 libxt6 libpci-dev && rm -rf /var/lib/apt/lists/*

#Installing Geck Driver
# !wget https://github.com/mozilla/geckodriver/releases/download/v0.24.0/geckodriver-v0.24.0-linux64.tar.gz
# !tar -xvzf geckodriver*
# !chmod +x geckodriver
# !export PATH=$PATH:/path-to-extracted-file/.

#Instal beautifulsoup
# %pip install beautifulsoup4
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.
# Collecting selenium
#   Downloading selenium-4.15.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting urllib3<3,>=1.26 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.23.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi>=2021.10.8 (from selenium)
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting attrs>=20.1.0 (from trio~=0.17->selenium)
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      -------------------------- ------------- 41.0/61.2 kB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 61.2/61.2 kB 1.6 MB/s eta 0:00:00
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting idna (from trio~=0.17->selenium)
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.5 kB ? eta -:--:--
#      ---------------------------------------- 61.5/61.5 kB 3.2 MB/s eta 0:00:00
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting cffi>=1.14 (from trio~=0.17->selenium)
#   Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata (1.5 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pycparser (from cffi>=1.14->trio~=0.17->selenium)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#      ---------------------------------------- 118.7/118.7 kB ? eta 0:00:00
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Downloading selenium-4.15.2-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/10.2 MB 22.0 MB/s eta 0:00:01
#    --------------- ------------------------ 3.9/10.2 MB 40.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.1/10.2 MB 43.5 MB/s eta 0:00:01
#    -------------------------------- ------- 8.4/10.2 MB 44.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 43.4 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    ---------------------------------------- 158.3/158.3 kB ? eta 0:00:00
# Downloading trio-0.23.1-py3-none-any.whl (448 kB)
#    ---------------------------------------- 0.0/448.3 kB ? eta -:--:--
#    ---------------------------------------- 448.3/448.3 kB ? eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#    ---------------------------------------- 104.6/104.6 kB ? eta 0:00:00
# Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.5 kB ? eta -:--:--
#    --------------------------------------- 181.5/181.5 kB 10.7 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: sortedcontainers, urllib3, sniffio, pysocks, pycparser, idna, h11, certifi, attrs, wsproto, outcome, cffi, trio, trio-websocket, selenium
# Successfully installed attrs-23.1.0 certifi-2023.7.22 cffi-1.16.0 h11-0.14.0 idna-3.4 outcome-1.3.0.post0 pycparser-2.21 pysocks-1.7.1 selenium-4.15.2 sniffio-1.3.0 sortedcontainers-2.4.0 trio-0.23.1 trio-websocket-0.11.1 urllib3-2.1.0 wsproto-1.2.0
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# tar: Error opening archive: Failed to open 'geckodriver*'
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.
# 'export' is not recognized as an internal or external command,
# operable program or batch file.
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ---------------------------------------- 0.0/143.0 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/143.0 kB 660.6 kB/s eta 0:00:01
#      ----------------------------- -------- 112.6/143.0 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 143.0/143.0 kB 1.4 MB/s eta 0:00:00
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.2 soupsieve-2.5

# %% [markdown]
# ### Import Dependencies

# %%
import selenium.webdriver as webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options as FirefoxOptions

import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By

import random
import time

# %% [markdown]
# ### Define Position and Location

# %%
## Enter a job position
position = "data+scientist"
## Enter a location (City, State or Zip or remote)
locations = "Canada"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])
print(url)
# Out:
# https://www.indeed.com/jobs?q=data+scientist&l=Canada

# %% [markdown]
# ### Set Path to Webdriver

# %%
driver_path = '/content/geckodriver'
firefox_driver_path = '/content/geckodriver'
user_agent = 'Mozilla'
firefox_options = FirefoxOptions()
firefox_options.add_argument('--headless')
driver = webdriver.Firefox(options=firefox_options)

# %% [markdown]
# ### Scrape Job Postings

# %%
## Number of postings to scrape
postings = 1000

jn=0
for i in range(0, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(3)

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')
    #print(jobs)

    for job in jobs:
        #print(job)
        result_html = job.get_attribute('innerHTML')
        #print(result_html)
        soup = BeautifulSoup(result_html, 'html.parser')
        #print(soup , '\n')

        jn += 1

        liens = job.find_elements(By.TAG_NAME, "a")
        #print(liens)
        links = liens[0].get_attribute("href")
        #print(links)

        title = soup.select('.jobTitle')[0].get_text().strip()
        print(title)

        #company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip()
        #print(company)
        try:
            company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip()
            #print(company)
        except:
            company = 'Nan'
        print(company)
        #location = soup.select('.companyLocation')[0].get_text().strip() #origional
        #location = soup.select('.company_location')[0].get_text().strip()
        location = soup.find_all(attrs={'data-testid': 'text-location'})[0].get_text().strip()
        print(location)
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''

        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))
# Out:
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number    1 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number    2 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number    3 added - Principal Statistician - CRO - Remote
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number    4 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number    5 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number    6 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number    7 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number    8 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Information Data Analyst/ Data Visualization Engineer
# Gazelle Global Consulting
# Dan, WV
# Job number    9 added - Information Data Analyst/ Data Visualization Engineer
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   10 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   11 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   12 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number   13 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   14 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   15 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   16 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   17 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   18 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   19 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   20 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   21 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   22 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   23 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number   24 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   25 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   26 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   27 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   28 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   29 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   30 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   31 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   32 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   33 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   34 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   35 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number   36 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   37 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   38 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   39 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   40 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Information Data Analyst/ Data Visualization Engineer
# Gazelle Global Consulting
# Dan, WV
# Job number   41 added - Information Data Analyst/ Data Visualization Engineer
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   42 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   43 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   44 added - Principal Statistician - CRO - Remote
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   45 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   46 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   47 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   48 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   49 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   50 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   51 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   52 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   53 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number   54 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   55 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   56 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   57 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   58 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   59 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   60 added - Principal Statistician - CRO - Remote
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   61 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   62 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   63 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   64 added - Principal Statistician - CRO - Remote
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number   65 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   66 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   67 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   68 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   69 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   70 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   71 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   72 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   73 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   74 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   75 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   76 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   77 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   78 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   79 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   80 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   81 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   82 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   83 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number   84 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   85 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   86 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   87 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   88 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   89 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   90 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number   91 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   92 added - Principal Statistical Programmer - CRO - Remote
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number   93 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   94 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   95 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number   96 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   97 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number   98 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Information Data Analyst/ Data Visualization Engineer
# Gazelle Global Consulting
# Dan, WV
# Job number   99 added - Information Data Analyst/ Data Visualization Engineer
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  100 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  101 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  102 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  103 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  104 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  105 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  106 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  107 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  108 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number  109 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  110 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  111 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  112 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number  113 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  114 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number  115 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  116 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  117 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number  118 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  119 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  120 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  121 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  122 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  123 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  124 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  125 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistician - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  126 added - Principal Statistician - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  127 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number  128 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  129 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  130 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  131 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  132 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  133 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number  134 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  135 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  136 added - Principal Statistical Programmer - CRO - Remote
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  137 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  138 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# Peraton
# United States
# Job number  139 added - Data Manager - DoD TS/SCI - Camp Humphrey - Korea
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  140 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# SK Battery America
# Kentucky
# Job number  141 added - VISS/AXIS Ai Developer - (Ai modeling, data engineering, X-ray imaging) - Kentucky (BOSK)
# Principal Statistical Programmer - CRO - Remote
# Compass Life Sciences
# Remote in United States
# Job number  142 added - Principal Statistical Programmer - CRO - Remote

# %%
dataframe.head()
# Out:
#                                                Title                Company  \
# 0  VISS/AXIS Ai Developer - (Ai modeling, data en...     SK Battery America
# 1  Data Manager - DoD TS/SCI - Camp Humphrey - Korea                Peraton
# 2              Principal Statistician - CRO - Remote  Compass Life Sciences
# 3    Principal Statistical Programmer - CRO - Remote  Compass Life Sciences
# 4  VISS/AXIS Ai Developer - (Ai modeling, data en...     SK Battery America
#
#                   Location Rating                       Date  \
# 0                 Kentucky    NaN  EmployerActive 4 days ago
# 1            United States    NaN  PostedPosted 30+ days ago
# 2  Remote in United States    NaN  PostedPosted 30+ days ago
# 3  Remote in United States    NaN  PostedPosted 30+ days ago
# 4                 Kentucky    NaN  EmployerActive 4 days ago
#
#                        Salary  \
# 0                         NaN
# 1  $112,000 - $179,000 a year
# 2             $140,000 a year
# 3             $145,000 a year
# 4                         NaN
#
#                                          Description  \
# 0  Come join us and build your future with SK bat...
# 1  Peraton Overview Peraton drives missions of co...
# 2  Compass Life Sciences have partnered with a ra...
# 3  Compass Life Sciences are working with a growt...
# 4  Data Management & Retrieval: Design and manage...
#
#                                                Links
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...

# %% [markdown]
# ### Scrape Full Job Descriptions

# %%
Links_list = dataframe['Links'].tolist()
#Links_list

# %%
print(len(Links_list))
# Out:
# 142

# %%
descriptions=[]
for i in Links_list:
    driver.get(i)
    driver.implicitly_wait(random.randint(3, 8))
    jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
    descriptions.append(jd)
    time.sleep(random.randint(5,10))

dataframe['Descriptions'] = descriptions
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Save Results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe.head()
# Out:
#                                                Title                 Company  \
# 0                            Data Scientist, Core AI                  Indeed
# 1         Post Marketing Pharmacovigilance Scientist              Medasource
# 2  Mid-level Conversational Banking AI Training –...        ALTA IT Services
# 3                                     Data Scientist  COGNIZE TECH SOLUTIONS
# 4                                     Data Scientist    The Chefs' Warehouse
#
#                      Location Rating                       Date  \
# 0                      Remote    NaN  EmployerActive 3 days ago
# 1                      Remote    NaN  PostedPosted 30+ days ago
# 2  Remote in Vienna, VA 22180    NaN     PostedPosted 1 day ago
# 3                      Remote    NaN  EmployerActive 2 days ago
# 4                      Remote    NaN   PostedPosted 24 days ago
#
#                        Salary  \
# 0  $122,000 - $178,000 a year
# 1          $80 - $120 an hour
# 2                         NaN
# 3    $65,000 - $80,000 a year
# 4    $90,000 - $98,000 a year
#
#                                          Description  \
# 0  Participate in code review and process innovat...
# 1  Irrespective, the PV Scientist is a critical t...
# 2  Ability to process large data sets and provide...
# 3   Using tools such as Tableau, Looker and Goog...
# 4  Strong knowledge of machine learning technique...
#
#                                                Links  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3  https://www.indeed.com/company/Cognize-tech-so...
# 4  https://www.indeed.com/rc/clk?jk=bcabc61c15e08...
#
#                                         Descriptions
# 0  Our Mission\nAs the world’s number 1 job site*...
# 1  Title: Post Marketing PV Scientist\nDuration: ...
# 2  Mid-level Conversational Banking AI Training –...
# 3  Apply Statistical and Machine Learning methods...
# 4  About The Chefs' Warehouse\nThe Chefs' Warehou...
